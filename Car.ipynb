# %%
# !pip install optuna
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: optuna in c:\users\hp\appdata\roaming\python\python311\site-packages (4.2.0)
# Requirement already satisfied: alembic>=1.5.0 in c:\users\hp\appdata\roaming\python\python311\site-packages (from optuna) (1.14.1)
# Requirement already satisfied: colorlog in c:\users\hp\appdata\roaming\python\python311\site-packages (from optuna) (6.9.0)
# Requirement already satisfied: numpy in c:\programdata\anaconda3\lib\site-packages (from optuna) (1.24.3)
# Requirement already satisfied: packaging>=20.0 in c:\users\hp\appdata\roaming\python\python311\site-packages (from optuna) (24.1)
# Requirement already satisfied: sqlalchemy>=1.4.2 in c:\programdata\anaconda3\lib\site-packages (from optuna) (1.4.39)
# Requirement already satisfied: tqdm in c:\programdata\anaconda3\lib\site-packages (from optuna) (4.65.0)
# Requirement already satisfied: PyYAML in c:\programdata\anaconda3\lib\site-packages (from optuna) (6.0)
# Requirement already satisfied: Mako in c:\users\hp\appdata\roaming\python\python311\site-packages (from alembic>=1.5.0->optuna) (1.3.9)
# Requirement already satisfied: typing-extensions>=4 in c:\users\hp\appdata\roaming\python\python311\site-packages (from alembic>=1.5.0->optuna) (4.12.2)
# Requirement already satisfied: greenlet!=0.4.17 in c:\programdata\anaconda3\lib\site-packages (from sqlalchemy>=1.4.2->optuna) (2.0.1)
# Requirement already satisfied: colorama in c:\programdata\anaconda3\lib\site-packages (from colorlog->optuna) (0.4.6)
# Requirement already satisfied: MarkupSafe>=0.9.2 in c:\programdata\anaconda3\lib\site-packages (from Mako->alembic>=1.5.0->optuna) (2.1.1)
# WARNING: Ignoring invalid distribution ~ensorflow-intel (C:\Users\hp\AppData\Roaming\Python\Python311\site-packages)
# WARNING: Ignoring invalid distribution ~ensorflow-intel (C:\Users\hp\AppData\Roaming\Python\Python311\site-packages)
# WARNING: Ignoring invalid distribution ~ensorflow-intel (C:\Users\hp\AppData\Roaming\Python\Python311\site-packages)
#
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import numpy as np
import pandas as pd
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer 
from sklearn.model_selection import train_test_split, RandomizedSearchCV
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor, StackingRegressor
from xgboost import XGBRegressor
import optuna
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, BatchNormalization
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.regularizers import l2
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score, classification_report, confusion_matrix
import os
from dotenv import load_dotenv
from sqlalchemy import create_engine

# %%
car = pd.read_excel('CarFINALdataset.xlsx')

# %%
car.head()
# Out:
#    User_ID  travelCode    Check-in    pickupLocation  dropoffLocation  \
# 0        0          22  02/27/2020          Johntown       Port Brian
# 1        0          45  08/06/2020         Owensland         Ruizfort
# 2        2         117  02/27/2020        Edwardview        Katiefort
# 3        2         119  03/12/2020      Moranborough   Lake Stephanie
# 4        2         153  11/05/2020  Port Kathrynstad  East Ronnieberg
#
#      carType rentalAgency  rentalDuration  Car_total_distance    fuelPolicy  \
# 0      Sedan         Sixt               3                 285       Prepaid
# 1      Sedan   Enterprise               3                 412  Full-to-Full
# 2      Sedan        Hertz               1                 433       Partial
# 3  Hatchback       Budget               3                 421  Full-to-Full
# 4      Sedan   Enterprise               5                 100       Prepaid
#
#   Car_bookingStatus  total_rent_price
# 0           Pending              3410
# 1           Pending              4644
# 2         Confirmed              4740
# 3         Confirmed              3744
# 4         Cancelled              1694

# %%
car
# Out:
#       User_ID  travelCode    Check-in    pickupLocation  dropoffLocation  \
# 0           0          22  02/27/2020          Johntown       Port Brian
# 1           0          45  08/06/2020         Owensland         Ruizfort
# 2           2         117  02/27/2020        Edwardview        Katiefort
# 3           2         119  03/12/2020      Moranborough   Lake Stephanie
# 4           2         153  11/05/2020  Port Kathrynstad  East Ronnieberg
# ...       ...         ...         ...               ...              ...
# 3768     1335      135831  12/29/2022        West Donna        Fordshire
# 3769     1335      135843  03/23/2023  East Crystalview       Lake Laura
# 3770     1337      135892  04/16/2020         Kylehaven         Johnland
# 3771     1339      135911  12/12/2019       South Julie        Brentside
# 3772     1339      135940  07/02/2020     Port Paulfurt      Timothyview
#
#         carType rentalAgency  rentalDuration  Car_total_distance  \
# 0         Sedan         Sixt               3                 285
# 1         Sedan   Enterprise               3                 412
# 2         Sedan        Hertz               1                 433
# 3     Hatchback       Budget               3                 421
# 4         Sedan   Enterprise               5                 100
# ...         ...          ...             ...                 ...
# 3768      Sedan   Enterprise               5                 123
# 3769      Sedan        Hertz               2                 229
# 3770     Luxury   Enterprise               1                 285
# 3771      Sedan         Sixt               1                 155
# 3772  Hatchback   Enterprise               2                 373
#
#         fuelPolicy Car_bookingStatus  total_rent_price
# 0          Prepaid           Pending              3410
# 1     Full-to-Full           Pending              4644
# 2          Partial         Confirmed              4740
# 3     Full-to-Full         Confirmed              3744
# 4          Prepaid         Cancelled              1694
# ...            ...               ...               ...
# 3768       Prepaid         Cancelled              1898
# 3769  Full-to-Full         Confirmed              2743
# 3770       Prepaid         Cancelled              6692
# 3771  Full-to-Full           Pending              1952
# 3772       Prepaid           Pending              3301
#
# [3773 rows x 12 columns]

# %%
passenger = pd.read_excel('PassengerFINALdataset.xlsx')

# %%
passenger.head()
# Out:
#    User_ID company             Name gender_x
# 0        0    4You        Roy Braun     male
# 1        1    4You   Joseph Holsten     male
# 2        2    4You    Wilma Mcinnis   female
# 3        3    4You     Paula Daniel   female
# 4        4    4You  Patricia Carson   female

# %%
car = pd.merge(car,passenger,how='left',on='User_ID')

# %%
car.head()
# Out:
#    User_ID  travelCode    Check-in    pickupLocation  dropoffLocation  \
# 0        0          22  02/27/2020          Johntown       Port Brian
# 1        0          45  08/06/2020         Owensland         Ruizfort
# 2        2         117  02/27/2020        Edwardview        Katiefort
# 3        2         119  03/12/2020      Moranborough   Lake Stephanie
# 4        2         153  11/05/2020  Port Kathrynstad  East Ronnieberg
#
#      carType rentalAgency  rentalDuration  Car_total_distance    fuelPolicy  \
# 0      Sedan         Sixt               3                 285       Prepaid
# 1      Sedan   Enterprise               3                 412  Full-to-Full
# 2      Sedan        Hertz               1                 433       Partial
# 3  Hatchback       Budget               3                 421  Full-to-Full
# 4      Sedan   Enterprise               5                 100       Prepaid
#
#   Car_bookingStatus  total_rent_price company           Name gender_x
# 0           Pending              3410    4You      Roy Braun     male
# 1           Pending              4644    4You      Roy Braun     male
# 2         Confirmed              4740    4You  Wilma Mcinnis   female
# 3         Confirmed              3744    4You  Wilma Mcinnis   female
# 4         Cancelled              1694    4You  Wilma Mcinnis   female

# %%
car.drop(['Name','User_ID','travelCode','company'],inplace=True,axis=1)

# %%
car
# Out:
#         Check-in    pickupLocation  dropoffLocation    carType rentalAgency  \
# 0     02/27/2020          Johntown       Port Brian      Sedan         Sixt
# 1     08/06/2020         Owensland         Ruizfort      Sedan   Enterprise
# 2     02/27/2020        Edwardview        Katiefort      Sedan        Hertz
# 3     03/12/2020      Moranborough   Lake Stephanie  Hatchback       Budget
# 4     11/05/2020  Port Kathrynstad  East Ronnieberg      Sedan   Enterprise
# ...          ...               ...              ...        ...          ...
# 3768  12/29/2022        West Donna        Fordshire      Sedan   Enterprise
# 3769  03/23/2023  East Crystalview       Lake Laura      Sedan        Hertz
# 3770  04/16/2020         Kylehaven         Johnland     Luxury   Enterprise
# 3771  12/12/2019       South Julie        Brentside      Sedan         Sixt
# 3772  07/02/2020     Port Paulfurt      Timothyview  Hatchback   Enterprise
#
#       rentalDuration  Car_total_distance    fuelPolicy Car_bookingStatus  \
# 0                  3                 285       Prepaid           Pending
# 1                  3                 412  Full-to-Full           Pending
# 2                  1                 433       Partial         Confirmed
# 3                  3                 421  Full-to-Full         Confirmed
# 4                  5                 100       Prepaid         Cancelled
# ...              ...                 ...           ...               ...
# 3768               5                 123       Prepaid         Cancelled
# 3769               2                 229  Full-to-Full         Confirmed
# 3770               1                 285       Prepaid         Cancelled
# 3771               1                 155  Full-to-Full           Pending
# 3772               2                 373       Prepaid           Pending
#
#       total_rent_price gender_x
# 0                 3410     male
# 1                 4644     male
# 2                 4740   female
# 3                 3744   female
# 4                 1694   female
# ...                ...      ...
# 3768              1898     male
# 3769              2743     male
# 3770              6692     male
# 3771              1952     male
# 3772              3301     male
#
# [3773 rows x 11 columns]

# %%
car['Car_check'] = pd.to_datetime(car['Check-in'])

# %%
car.drop('Check-in',inplace=True,axis=1)

# %%
car['Weekend_Checkin'] = (car['Car_check'].dt.weekday >= 5).astype(int)

# %%
car['Month_checkin'] = car['Car_check'].dt.month

# %%
car.head()
# Out:
#      pickupLocation  dropoffLocation    carType rentalAgency  rentalDuration  \
# 0          Johntown       Port Brian      Sedan         Sixt               3
# 1         Owensland         Ruizfort      Sedan   Enterprise               3
# 2        Edwardview        Katiefort      Sedan        Hertz               1
# 3      Moranborough   Lake Stephanie  Hatchback       Budget               3
# 4  Port Kathrynstad  East Ronnieberg      Sedan   Enterprise               5
#
#    Car_total_distance    fuelPolicy Car_bookingStatus  total_rent_price  \
# 0                 285       Prepaid           Pending              3410
# 1                 412  Full-to-Full           Pending              4644
# 2                 433       Partial         Confirmed              4740
# 3                 421  Full-to-Full         Confirmed              3744
# 4                 100       Prepaid         Cancelled              1694
#
#   gender_x  Car_check  Weekend_Checkin  Month_checkin
# 0     male 2020-02-27                0              2
# 1     male 2020-08-06                0              8
# 2   female 2020-02-27                0              2
# 3   female 2020-03-12                0              3
# 4   female 2020-11-05                0             11

# %%
car1 = car.copy(deep=True)

# %%
car1
# Out:
#         pickupLocation  dropoffLocation    carType rentalAgency  \
# 0             Johntown       Port Brian      Sedan         Sixt
# 1            Owensland         Ruizfort      Sedan   Enterprise
# 2           Edwardview        Katiefort      Sedan        Hertz
# 3         Moranborough   Lake Stephanie  Hatchback       Budget
# 4     Port Kathrynstad  East Ronnieberg      Sedan   Enterprise
# ...                ...              ...        ...          ...
# 3768        West Donna        Fordshire      Sedan   Enterprise
# 3769  East Crystalview       Lake Laura      Sedan        Hertz
# 3770         Kylehaven         Johnland     Luxury   Enterprise
# 3771       South Julie        Brentside      Sedan         Sixt
# 3772     Port Paulfurt      Timothyview  Hatchback   Enterprise
#
#       rentalDuration  Car_total_distance    fuelPolicy Car_bookingStatus  \
# 0                  3                 285       Prepaid           Pending
# 1                  3                 412  Full-to-Full           Pending
# 2                  1                 433       Partial         Confirmed
# 3                  3                 421  Full-to-Full         Confirmed
# 4                  5                 100       Prepaid         Cancelled
# ...              ...                 ...           ...               ...
# 3768               5                 123       Prepaid         Cancelled
# 3769               2                 229  Full-to-Full         Confirmed
# 3770               1                 285       Prepaid         Cancelled
# 3771               1                 155  Full-to-Full           Pending
# 3772               2                 373       Prepaid           Pending
#
#       total_rent_price gender_x  Car_check  Weekend_Checkin  Month_checkin
# 0                 3410     male 2020-02-27                0              2
# 1                 4644     male 2020-08-06                0              8
# 2                 4740   female 2020-02-27                0              2
# 3                 3744   female 2020-03-12                0              3
# 4                 1694   female 2020-11-05                0             11
# ...                ...      ...        ...              ...            ...
# 3768              1898     male 2022-12-29                0             12
# 3769              2743     male 2023-03-23                0              3
# 3770              6692     male 2020-04-16                0              4
# 3771              1952     male 2019-12-12                0             12
# 3772              3301     male 2020-07-02                0              7
#
# [3773 rows x 13 columns]

# %%
X = car.drop('total_rent_price',axis=1)
y = car['total_rent_price']

# %%
num_feature = X.select_dtypes(include=['int64','float64']).columns
cat_feature = X.select_dtypes(include=['object']).columns

# %%
num_transformer = Pipeline([('imputer',SimpleImputer(strategy='median')),
                           ('scaler',StandardScaler())])

# %%
cat_transformer = Pipeline([('imputer',SimpleImputer(strategy='most_frequent')),
                           ('onehot',OneHotEncoder(handle_unknown='ignore',sparse_output=False))])

# %%
preprocessor = ColumnTransformer([
    ('num',num_transformer,num_feature),
    ('cat',cat_transformer,cat_feature)
])

# %%
X_transformed = preprocessor.fit_transform(X)

# %%
feature_names = X.columns

# %%
X_train,X_test,y_train,y_test = train_test_split(X_transformed,y,test_size=0.2,random_state=42)

# %%
def objective(trial):
    model = XGBRegressor(
        n_estimators=trial.suggest_int('n_estimators', 100, 500),
        learning_rate=trial.suggest_float('learning_rate', 0.01, 0.2),
        max_depth=trial.suggest_int('max_depth', 3, 10),
        subsample=trial.suggest_float('subsample', 0.5, 1.0),
        colsample_bytree=trial.suggest_float('colsample_bytree', 0.5, 1.0),
        random_state=42
    )
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    return mean_squared_error(y_test, y_pred)

# %%
study = optuna.create_study(direction='minimize')
study.optimize(objective, n_trials=30)
best_params = study.best_params
# Out:
# [I 2025-02-17 17:21:01,750] A new study created in memory with name: no-name-2f3ffb1f-b9a6-4a2e-af70-af195f0102de
# [I 2025-02-17 17:21:28,932] Trial 0 finished with value: 7662.91317734897 and parameters: {'n_estimators': 298, 'learning_rate': 0.024819110624814483, 'max_depth': 9, 'subsample': 0.6186081171954754, 'colsample_bytree': 0.7870590392413841}. Best is trial 0 with value: 7662.91317734897.
# [I 2025-02-17 17:21:44,709] Trial 1 finished with value: 10670.259721459719 and parameters: {'n_estimators': 223, 'learning_rate': 0.07979066361869441, 'max_depth': 9, 'subsample': 0.5785289755103764, 'colsample_bytree': 0.7502154362606421}. Best is trial 0 with value: 7662.91317734897.
# [I 2025-02-17 17:21:57,762] Trial 2 finished with value: 2118.6389690400206 and parameters: {'n_estimators': 479, 'learning_rate': 0.12843665390594952, 'max_depth': 4, 'subsample': 0.6180954121411721, 'colsample_bytree': 0.6375038389774774}. Best is trial 2 with value: 2118.6389690400206.
# [I 2025-02-17 17:22:09,764] Trial 3 finished with value: 2058.1289742579474 and parameters: {'n_estimators': 239, 'learning_rate': 0.041878549874318, 'max_depth': 5, 'subsample': 0.8759103793743368, 'colsample_bytree': 0.8190786187216719}. Best is trial 3 with value: 2058.1289742579474.
# [I 2025-02-17 17:22:40,478] Trial 4 finished with value: 1405.4139560115307 and parameters: {'n_estimators': 273, 'learning_rate': 0.05110300329671666, 'max_depth': 10, 'subsample': 0.9406403749661969, 'colsample_bytree': 0.9604767271213273}. Best is trial 4 with value: 1405.4139560115307.
# [I 2025-02-17 17:22:51,682] Trial 5 finished with value: 10953.959461105793 and parameters: {'n_estimators': 105, 'learning_rate': 0.12882755583966074, 'max_depth': 10, 'subsample': 0.8177135707785483, 'colsample_bytree': 0.8999250765573461}. Best is trial 4 with value: 1405.4139560115307.
# [I 2025-02-17 17:23:02,200] Trial 6 finished with value: 1394.732779768435 and parameters: {'n_estimators': 121, 'learning_rate': 0.1565899398198626, 'max_depth': 9, 'subsample': 0.8609068298750171, 'colsample_bytree': 0.9907699013205375}. Best is trial 6 with value: 1394.732779768435.
# [I 2025-02-17 17:23:17,108] Trial 7 finished with value: 17145.389305085406 and parameters: {'n_estimators': 384, 'learning_rate': 0.14643392156115023, 'max_depth': 9, 'subsample': 0.8719802011644513, 'colsample_bytree': 0.5368460451413373}. Best is trial 6 with value: 1394.732779768435.
# [I 2025-02-17 17:23:31,888] Trial 8 finished with value: 6695.001218752652 and parameters: {'n_estimators': 169, 'learning_rate': 0.05189145461331892, 'max_depth': 8, 'subsample': 0.6583716950235772, 'colsample_bytree': 0.8280440082396112}. Best is trial 6 with value: 1394.732779768435.
# [I 2025-02-17 17:23:58,356] Trial 9 finished with value: 1291.7747394775072 and parameters: {'n_estimators': 411, 'learning_rate': 0.06160363732412149, 'max_depth': 9, 'subsample': 0.8267322028473019, 'colsample_bytree': 0.9908560793544603}. Best is trial 9 with value: 1291.7747394775072.
# [I 2025-02-17 17:24:11,883] Trial 10 finished with value: 4783.910065976471 and parameters: {'n_estimators': 404, 'learning_rate': 0.19540838740494362, 'max_depth': 6, 'subsample': 0.7269347049077259, 'colsample_bytree': 0.6289217519388022}. Best is trial 9 with value: 1291.7747394775072.
# [I 2025-02-17 17:24:27,461] Trial 11 finished with value: 1400.5315420065988 and parameters: {'n_estimators': 393, 'learning_rate': 0.1759748294158148, 'max_depth': 7, 'subsample': 0.7722498047054096, 'colsample_bytree': 0.9967141788728504}. Best is trial 9 with value: 1291.7747394775072.
# [I 2025-02-17 17:24:44,523] Trial 12 finished with value: 2962.01233801824 and parameters: {'n_estimators': 488, 'learning_rate': 0.08266238498037452, 'max_depth': 7, 'subsample': 0.9898668164036231, 'colsample_bytree': 0.9114348456402619}. Best is trial 9 with value: 1291.7747394775072.
# [I 2025-02-17 17:24:59,641] Trial 13 finished with value: 5462.232841689663 and parameters: {'n_estimators': 350, 'learning_rate': 0.09549769861751384, 'max_depth': 8, 'subsample': 0.8730441856599509, 'colsample_bytree': 0.8901432131285605}. Best is trial 9 with value: 1291.7747394775072.
# [I 2025-02-17 17:25:07,489] Trial 14 finished with value: 1486.2740869914608 and parameters: {'n_estimators': 104, 'learning_rate': 0.16123200463591897, 'max_depth': 8, 'subsample': 0.5000780891347345, 'colsample_bytree': 0.9794387024641191}. Best is trial 9 with value: 1291.7747394775072.
# [I 2025-02-17 17:25:22,482] Trial 15 finished with value: 13689.346700560385 and parameters: {'n_estimators': 180, 'learning_rate': 0.10717901380651466, 'max_depth': 10, 'subsample': 0.7297214640408278, 'colsample_bytree': 0.8677784394915022}. Best is trial 9 with value: 1291.7747394775072.
# [I 2025-02-17 17:25:49,921] Trial 16 finished with value: 1432.962567531964 and parameters: {'n_estimators': 442, 'learning_rate': 0.014567347049941379, 'max_depth': 6, 'subsample': 0.8010172057228186, 'colsample_bytree': 0.9317638784729546}. Best is trial 9 with value: 1291.7747394775072.
# [I 2025-02-17 17:26:09,047] Trial 17 finished with value: 13501.12431512142 and parameters: {'n_estimators': 338, 'learning_rate': 0.06955264147751437, 'max_depth': 9, 'subsample': 0.9391954743943829, 'colsample_bytree': 0.689236459391895}. Best is trial 9 with value: 1291.7747394775072.
# [I 2025-02-17 17:26:14,668] Trial 18 finished with value: 5764.711506275384 and parameters: {'n_estimators': 160, 'learning_rate': 0.11574844619869104, 'max_depth': 3, 'subsample': 0.8244820095677741, 'colsample_bytree': 0.5023664039003475}. Best is trial 9 with value: 1291.7747394775072.
# [I 2025-02-17 17:26:32,704] Trial 19 finished with value: 1357.2830561080566 and parameters: {'n_estimators': 343, 'learning_rate': 0.18963669377006043, 'max_depth': 8, 'subsample': 0.6993997232642949, 'colsample_bytree': 0.9989856844812905}. Best is trial 9 with value: 1291.7747394775072.
# [I 2025-02-17 17:26:50,198] Trial 20 finished with value: 1416.0522279281195 and parameters: {'n_estimators': 436, 'learning_rate': 0.19210836473822077, 'max_depth': 7, 'subsample': 0.6835459011773625, 'colsample_bytree': 0.9429252433329516}. Best is trial 9 with value: 1291.7747394775072.
# [I 2025-02-17 17:27:05,125] Trial 21 finished with value: 1603.5327430811346 and parameters: {'n_estimators': 340, 'learning_rate': 0.17439384664080632, 'max_depth': 8, 'subsample': 0.753757157610378, 'colsample_bytree': 0.9817558708544679}. Best is trial 9 with value: 1291.7747394775072.
# [I 2025-02-17 17:27:20,873] Trial 22 finished with value: 1394.419197148647 and parameters: {'n_estimators': 363, 'learning_rate': 0.15540732594347362, 'max_depth': 9, 'subsample': 0.8480186897328678, 'colsample_bytree': 0.9998577380936399}. Best is trial 9 with value: 1291.7747394775072.
# [I 2025-02-17 17:27:38,251] Trial 23 finished with value: 13191.828698346862 and parameters: {'n_estimators': 365, 'learning_rate': 0.17906602775212, 'max_depth': 8, 'subsample': 0.6958934922528084, 'colsample_bytree': 0.8669435798652554}. Best is trial 9 with value: 1291.7747394775072.
# [I 2025-02-17 17:27:55,893] Trial 24 finished with value: 1579.4481501011066 and parameters: {'n_estimators': 301, 'learning_rate': 0.1380693179295614, 'max_depth': 10, 'subsample': 0.9177951413903764, 'colsample_bytree': 0.9412512906839808}. Best is trial 9 with value: 1291.7747394775072.
# [I 2025-02-17 17:28:14,449] Trial 25 finished with value: 16741.51581916041 and parameters: {'n_estimators': 441, 'learning_rate': 0.1609809838702356, 'max_depth': 9, 'subsample': 0.7849248851739203, 'colsample_bytree': 0.8560673578599726}. Best is trial 9 with value: 1291.7747394775072.
# [I 2025-02-17 17:28:25,265] Trial 26 finished with value: 1520.8976871780903 and parameters: {'n_estimators': 315, 'learning_rate': 0.19661950208921555, 'max_depth': 8, 'subsample': 0.9985387392564907, 'colsample_bytree': 0.9994120800663558}. Best is trial 9 with value: 1291.7747394775072.
# [I 2025-02-17 17:28:43,636] Trial 27 finished with value: 1115.839537906543 and parameters: {'n_estimators': 418, 'learning_rate': 0.06721791529788909, 'max_depth': 7, 'subsample': 0.8251228139009782, 'colsample_bytree': 0.9226276797140797}. Best is trial 27 with value: 1115.839537906543.
# [I 2025-02-17 17:29:01,240] Trial 28 finished with value: 965.3643333695484 and parameters: {'n_estimators': 420, 'learning_rate': 0.06750619503361265, 'max_depth': 6, 'subsample': 0.7156642253313118, 'colsample_bytree': 0.9203754130341333}. Best is trial 28 with value: 965.3643333695484.
# [I 2025-02-17 17:29:19,695] Trial 29 finished with value: 2140.010120145039 and parameters: {'n_estimators': 419, 'learning_rate': 0.031271742586304385, 'max_depth': 5, 'subsample': 0.7544431495854348, 'colsample_bytree': 0.7656332711972351}. Best is trial 28 with value: 965.3643333695484.

# %%
best_xgb = XGBRegressor(**best_params)
best_xgb.fit(X_train, y_train)
y_pred_xgb = best_xgb.predict(X_test)

# %%
stacked_model = StackingRegressor(
    estimators=[('xgb', best_xgb)],
    final_estimator=XGBRegressor(n_estimators=100, learning_rate=0.05, max_depth=3, random_state=42)
)

# %%
stacked_model.fit(X_train, y_train)
y_pred_stack = stacked_model.predict(X_test)

# %%
def build_nn():
    model = Sequential([
        Dense(128, activation='relu', kernel_regularizer=l2(0.001), input_shape=(X_train.shape[1],)),
        BatchNormalization(),
        Dropout(0.3),
        Dense(64, activation='relu', kernel_regularizer=l2(0.001)),
        BatchNormalization(),
        Dropout(0.3),
        Dense(32, activation='relu', kernel_regularizer=l2(0.001)),
        Dense(1)
    ])
    model.compile(optimizer=Adam(learning_rate=0.01), loss='mse', metrics=['mae'])
    return model

nn_model = build_nn()
nn_callbacks = [
    ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=5, min_lr=1e-5),
    EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
]
nn_model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=100, batch_size=32, verbose=1, callbacks=nn_callbacks)

y_pred_nn = nn_model.predict(X_test).flatten()
# Out:
# C:\Users\hp\AppData\Roaming\Python\Python311\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/100
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 8s 25ms/step - loss: 20931218.0000 - mae: 3981.3125 - val_loss: 1234057.1250 - val_mae: 843.7166 - learning_rate: 0.0100
# Epoch 2/100
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 1920023.5000 - mae: 1108.3278 - val_loss: 1161221.6250 - val_mae: 973.7256 - learning_rate: 0.0100
# Epoch 3/100
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 917589.6250 - mae: 746.7968 - val_loss: 158101.0312 - val_mae: 321.3967 - learning_rate: 0.0100
# Epoch 4/100
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 727435.1875 - mae: 630.9664 - val_loss: 336486.2812 - val_mae: 443.4665 - learning_rate: 0.0100
# Epoch 5/100
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 597226.3125 - mae: 581.2196 - val_loss: 73463.5547 - val_mae: 219.7439 - learning_rate: 0.0100
# Epoch 6/100
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 538436.8125 - mae: 555.3964 - val_loss: 55788.9922 - val_mae: 178.3197 - learning_rate: 0.0100
# Epoch 7/100
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 545695.0000 - mae: 531.3930 - val_loss: 144693.6406 - val_mae: 299.9209 - learning_rate: 0.0100
# Epoch 8/100
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 709524.4375 - mae: 608.8005 - val_loss: 49607.4375 - val_mae: 185.0186 - learning_rate: 0.0100
# Epoch 9/100
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 568218.2500 - mae: 562.8765 - val_loss: 33509.7578 - val_mae: 141.8985 - learning_rate: 0.0100
# Epoch 10/100
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 489365.1562 - mae: 517.1177 - val_loss: 65222.3945 - val_mae: 205.8296 - learning_rate: 0.0100
# Epoch 11/100
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 525786.6250 - mae: 542.2924 - val_loss: 77995.6016 - val_mae: 214.4528 - learning_rate: 0.0100
# Epoch 12/100
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 567695.1875 - mae: 553.6808 - val_loss: 75726.7734 - val_mae: 193.2588 - learning_rate: 0.0100
# Epoch 13/100
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 517951.2500 - mae: 529.6449 - val_loss: 89880.9141 - val_mae: 248.5652 - learning_rate: 0.0100
# Epoch 14/100
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 500990.4688 - mae: 538.1309 - val_loss: 49156.0352 - val_mae: 182.1581 - learning_rate: 0.0100
# Epoch 15/100
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 511516.2812 - mae: 532.2922 - val_loss: 32189.7930 - val_mae: 135.4522 - learning_rate: 0.0020
# Epoch 16/100
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 515929.4375 - mae: 532.1385 - val_loss: 51824.7148 - val_mae: 163.7936 - learning_rate: 0.0020
# Epoch 17/100
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - loss: 514583.6875 - mae: 539.4036 - val_loss: 35715.0430 - val_mae: 134.9445 - learning_rate: 0.0020
# Epoch 18/100
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 528091.1875 - mae: 533.5247 - val_loss: 48679.7578 - val_mae: 156.5087 - learning_rate: 0.0020
# Epoch 19/100
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 436797.0938 - mae: 489.3235 - val_loss: 55670.7500 - val_mae: 167.2597 - learning_rate: 0.0020
# Epoch 20/100
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 583557.6875 - mae: 562.0668 - val_loss: 37823.3867 - val_mae: 143.0856 - learning_rate: 0.0020
# Epoch 21/100
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - loss: 476359.9375 - mae: 502.5780 - val_loss: 47572.7617 - val_mae: 150.0640 - learning_rate: 4.0000e-04
# Epoch 22/100
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 505818.8750 - mae: 522.7715 - val_loss: 50372.4766 - val_mae: 155.9476 - learning_rate: 4.0000e-04
# Epoch 23/100
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 455280.6875 - mae: 488.4271 - val_loss: 51905.6680 - val_mae: 158.3464 - learning_rate: 4.0000e-04
# Epoch 24/100
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 494308.0625 - mae: 522.8104 - val_loss: 53465.7266 - val_mae: 161.3282 - learning_rate: 4.0000e-04
# Epoch 25/100
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 451369.7500 - mae: 492.5548 - val_loss: 54549.3633 - val_mae: 163.9270 - learning_rate: 4.0000e-04
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step

# %%
def evaluate_model(name, y_true, y_pred):
    r2 = r2_score(y_true, y_pred)
    mae = mean_absolute_error(y_true, y_pred)
    rmse = np.sqrt(mean_squared_error(y_true, y_pred))
    # classification__report = classification_report(y_true,y_pred)
    # confusion__matrix = confusion_matrix(y_true,y_pred)
    print(f"\n {name} Performance:")
    print(f"R² Score: {r2:.4f}")
    print(f"MAE: {mae:.4f}")
    print(f"RMSE: {rmse:.4f}")
    
evaluate_model("Optimized XGBoost", y_test, y_pred_xgb)
evaluate_model("Stacking Model", y_test, y_pred_stack)
evaluate_model("Neural Network", y_test, y_pred_nn)
# Out:
#  Optimized XGBoost Performance:
# R² Score: 0.9998
# MAE: 27.0805
# RMSE: 35.9514
#
#  Stacking Model Performance:
# R² Score: 0.9996
# MAE: 34.8109
# RMSE: 48.3622
#
#  Neural Network Performance:
# R² Score: 0.9943
# MAE: 135.4522
# RMSE: 179.3486

# %%
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, BatchNormalization, Dropout, LeakyReLU, Add, Input
from tensorflow.keras.regularizers import l2
from tensorflow.keras.optimizers import AdamW
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping
from sklearn.preprocessing import StandardScaler
import numpy as np



def build_nn():
    inputs = Input(shape=(X_train.shape[1],))
    x = Dense(128, kernel_regularizer=l2(0.001))(inputs)
    x = BatchNormalization()(x)
    x = LeakyReLU()(x)
    x = Dropout(0.2)(x)

    x1 = Dense(64, kernel_regularizer=l2(0.001))(x)
    x1 = BatchNormalization()(x1)
    x1 = LeakyReLU()(x1)
    x1 = Dropout(0.2)(x1)

    x2 = Dense(128, kernel_regularizer=l2(0.001))(x1)  # Ensuring same shape as `x`
    x2 = BatchNormalization()(x2)
    x2 = LeakyReLU()(x2)
    x2 = Dropout(0.2)(x2)

    # Residual connection (now both are (128,))
    x3 = Add()([x, x2])
    
    outputs = Dense(1)(x3)

    model = Model(inputs=inputs, outputs=outputs)
    model.compile(optimizer=AdamW(learning_rate=0.005), loss='mse', metrics=['mae'])
    return model

nn_model = build_nn()
nn_callbacks = [
    ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=5, min_lr=1e-5),
    EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
]

nn_model.fit(X_train, y_train, validation_data=(X_test, y_test), 
             epochs=200, batch_size=32, verbose=1, callbacks=nn_callbacks)

y_pred_nn = nn_model.predict(X_test).flatten()
# Out:
# Epoch 1/200
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 8s 24ms/step - loss: 22948020.0000 - mae: 4165.2476 - val_loss: 22248468.0000 - val_mae: 4135.4673 - learning_rate: 0.0050
# Epoch 2/200
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 19880568.0000 - mae: 3934.7280 - val_loss: 16671508.0000 - val_mae: 3671.4983 - learning_rate: 0.0050
# Epoch 3/200
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 16054231.0000 - mae: 3621.5251 - val_loss: 10213079.0000 - val_mae: 3004.3381 - learning_rate: 0.0050
# Epoch 4/200
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 10794491.0000 - mae: 3044.4666 - val_loss: 5665068.5000 - val_mae: 2314.1086 - learning_rate: 0.0050
# Epoch 5/200
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 6823207.0000 - mae: 2461.3994 - val_loss: 3280339.0000 - val_mae: 1760.7616 - learning_rate: 0.0050
# Epoch 6/200
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 3915817.5000 - mae: 1847.9645 - val_loss: 1726540.0000 - val_mae: 1234.0496 - learning_rate: 0.0050
# Epoch 7/200
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - loss: 2051630.2500 - mae: 1278.7847 - val_loss: 731184.0625 - val_mae: 762.0504 - learning_rate: 0.0050
# Epoch 8/200
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - loss: 1065001.3750 - mae: 866.0035 - val_loss: 419769.5625 - val_mae: 536.5795 - learning_rate: 0.0050
# Epoch 9/200
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 600593.1250 - mae: 619.5319 - val_loss: 232760.0469 - val_mae: 391.8173 - learning_rate: 0.0050
# Epoch 10/200
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - loss: 483663.5312 - mae: 546.8710 - val_loss: 217998.0781 - val_mae: 354.0668 - learning_rate: 0.0050
# Epoch 11/200
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 374486.0000 - mae: 461.1274 - val_loss: 176312.7031 - val_mae: 320.9536 - learning_rate: 0.0050
# Epoch 12/200
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 366405.8125 - mae: 443.6995 - val_loss: 170119.2656 - val_mae: 310.9343 - learning_rate: 0.0050
# Epoch 13/200
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 281373.4375 - mae: 391.2199 - val_loss: 187688.3438 - val_mae: 302.6985 - learning_rate: 0.0050
# Epoch 14/200
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 362539.4062 - mae: 452.7288 - val_loss: 215666.1406 - val_mae: 316.7867 - learning_rate: 0.0050
# Epoch 15/200
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - loss: 338611.9688 - mae: 442.2493 - val_loss: 191432.2188 - val_mae: 302.4780 - learning_rate: 0.0050
# Epoch 16/200
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 349581.0312 - mae: 434.3372 - val_loss: 209029.1094 - val_mae: 311.7183 - learning_rate: 0.0050
# Epoch 17/200
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - loss: 273869.4688 - mae: 382.9294 - val_loss: 196385.2344 - val_mae: 308.5839 - learning_rate: 0.0050
# Epoch 18/200
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - loss: 275259.5000 - mae: 378.5216 - val_loss: 220898.7812 - val_mae: 310.0987 - learning_rate: 1.0000e-03
# Epoch 19/200
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 271021.9688 - mae: 371.3492 - val_loss: 216243.5156 - val_mae: 307.2679 - learning_rate: 1.0000e-03
# Epoch 20/200
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 325747.9688 - mae: 410.0432 - val_loss: 229778.2812 - val_mae: 315.5360 - learning_rate: 1.0000e-03
# Epoch 21/200
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 302408.5625 - mae: 411.7769 - val_loss: 228461.7344 - val_mae: 314.0514 - learning_rate: 1.0000e-03
# Epoch 22/200
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 259716.3906 - mae: 370.6240 - val_loss: 228296.2500 - val_mae: 314.2163 - learning_rate: 1.0000e-03
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step

# %%
evaluate_model("Neural Network", y_test, y_pred_nn)
# Out:
#  Neural Network Performance:
# R² Score: 0.9701
# MAE: 310.9343
# RMSE: 412.4315

# %%
# !pip install scikeras
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# WARNING: Ignoring invalid distribution ~ensorflow-intel (C:\Users\hp\AppData\Roaming\Python\Python311\site-packages)
# WARNING: Ignoring invalid distribution ~ensorflow-intel (C:\Users\hp\AppData\Roaming\Python\Python311\site-packages)
# WARNING: Ignoring invalid distribution ~ensorflow-intel (C:\Users\hp\AppData\Roaming\Python\Python311\site-packages)
#
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: scikeras in c:\users\hp\appdata\roaming\python\python311\site-packages (0.13.0)
# Requirement already satisfied: keras>=3.2.0 in c:\users\hp\appdata\roaming\python\python311\site-packages (from scikeras) (3.3.3)
# Requirement already satisfied: scikit-learn>=1.4.2 in c:\users\hp\appdata\roaming\python\python311\site-packages (from scikeras) (1.5.1)
# Requirement already satisfied: absl-py in c:\users\hp\appdata\roaming\python\python311\site-packages (from keras>=3.2.0->scikeras) (2.1.0)
# Requirement already satisfied: numpy in c:\programdata\anaconda3\lib\site-packages (from keras>=3.2.0->scikeras) (1.24.3)
# Requirement already satisfied: rich in c:\users\hp\appdata\roaming\python\python311\site-packages (from keras>=3.2.0->scikeras) (13.7.1)
# Requirement already satisfied: namex in c:\users\hp\appdata\roaming\python\python311\site-packages (from keras>=3.2.0->scikeras) (0.0.8)
# Requirement already satisfied: h5py in c:\users\hp\appdata\roaming\python\python311\site-packages (from keras>=3.2.0->scikeras) (3.11.0)
# Requirement already satisfied: optree in c:\users\hp\appdata\roaming\python\python311\site-packages (from keras>=3.2.0->scikeras) (0.11.0)
# Requirement already satisfied: ml-dtypes in c:\users\hp\appdata\roaming\python\python311\site-packages (from keras>=3.2.0->scikeras) (0.3.2)
# Requirement already satisfied: scipy>=1.6.0 in c:\programdata\anaconda3\lib\site-packages (from scikit-learn>=1.4.2->scikeras) (1.10.1)
# Requirement already satisfied: joblib>=1.2.0 in c:\programdata\anaconda3\lib\site-packages (from scikit-learn>=1.4.2->scikeras) (1.2.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\hp\appdata\roaming\python\python311\site-packages (from scikit-learn>=1.4.2->scikeras) (3.5.0)
# Requirement already satisfied: typing-extensions>=4.0.0 in c:\users\hp\appdata\roaming\python\python311\site-packages (from optree->keras>=3.2.0->scikeras) (4.12.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\programdata\anaconda3\lib\site-packages (from rich->keras>=3.2.0->scikeras) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\programdata\anaconda3\lib\site-packages (from rich->keras>=3.2.0->scikeras) (2.15.1)
# Requirement already satisfied: mdurl~=0.1 in c:\programdata\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.2.0->scikeras) (0.1.0)

# %%
from sklearn.ensemble import StackingRegressor
from scikeras.wrappers import KerasRegressor  # Corrected import

def build_nn_wrapper():
    return build_nn()

nn_wrapper = KerasRegressor(build_fn=build_nn_wrapper, epochs=100, batch_size=32, verbose=0)

stacked_model = StackingRegressor(
    estimators=[('xgb', best_xgb), ('nn', nn_wrapper)],
    final_estimator=XGBRegressor(n_estimators=100, learning_rate=0.05, max_depth=3, random_state=42)
)

stacked_model.fit(X_train, y_train)
y_pred_stacked = stacked_model.predict(X_test)
# Out:
# C:\Users\hp\AppData\Roaming\Python\Python311\site-packages\scikeras\wrappers.py:925: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# C:\Users\hp\AppData\Roaming\Python\Python311\site-packages\scikeras\wrappers.py:925: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# C:\Users\hp\AppData\Roaming\Python\Python311\site-packages\scikeras\wrappers.py:925: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# C:\Users\hp\AppData\Roaming\Python\Python311\site-packages\scikeras\wrappers.py:925: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# C:\Users\hp\AppData\Roaming\Python\Python311\site-packages\scikeras\wrappers.py:925: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# C:\Users\hp\AppData\Roaming\Python\Python311\site-packages\scikeras\wrappers.py:925: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)

# %%
evaluate_model("Sta", y_test, y_pred_stacked)
# Out:
#  Sta Performance:
# R² Score: 0.9996
# MAE: 34.6844
# RMSE: 48.1538

# %%
import numpy as np
X_train = np.log1p(X_train)
X_test = np.log1p(X_test)
y_train = np.log1p(y_train)
y_test = np.log1p(y_test)
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_1028\1480503297.py:2: RuntimeWarning: invalid value encountered in log1p
#   X_train = np.log1p(X_train)
# C:\Users\hp\AppData\Local\Temp\ipykernel_1028\1480503297.py:3: RuntimeWarning: invalid value encountered in log1p
#   X_test = np.log1p(X_test)

# %%
import numpy as np
print(np.isnan(X_train).sum())  # Check the number of NaN values in X_train
print(np.isnan(X_test).sum())   # Check the number of NaN values in X_test
# Out:
# 0
# 0

# %%
print((X_train < -1).sum())  # Checking for values less than -1 in X_train
print((X_test < -1).sum())   # Checking for values less than -1 in X_test
# Out:
# 1830
# 444

# %%
import numpy as np

# Identify columns with negative values in X_train
negative_columns_train = np.any(X_train < -1, axis=0)
print("Columns in X_train with negative values:")
print(np.array(feature_names)[negative_columns_train])  # feature_names should be your original column names

# Identify columns with negative values in X_test
negative_columns_test = np.any(X_test < -1, axis=0)
print("Columns in X_test with negative values:")
print(np.array(feature_names)[negative_columns_test])
# Out:
# Columns in X_train with negative values:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[64], line 6
#       4 negative_columns_train = np.any(X_train < -1, axis=0)
#       5 print("Columns in X_train with negative values:")
# ----> 6 print(np.array(feature_names)[negative_columns_train])  # feature_names should be your original column names
#       8 # Identify columns with negative values in X_test
#       9 negative_columns_test = np.any(X_test < -1, axis=0)
#
# IndexError: boolean index did not match indexed array along dimension 0; dimension is 12 but corresponding boolean dimension is 6703

# %%
X_train
# Out:
# array([[ 0.72286285,  1.53677057,  0.13450465, ...,  0.        ,
#          1.        ,  0.        ],
#        [ 0.02101994, -0.50936861, -0.70155141, ...,  0.        ,
#          0.        ,  1.        ],
#        [-1.38266586, -1.57089946, -0.42286606, ...,  0.        ,
#          0.        ,  1.        ],
#        ...,
#        [-0.68082296, -0.54782987, -1.25892212, ...,  1.        ,
#          0.        ,  0.        ],
#        [-1.38266586, -1.52474595, -1.25892212, ...,  0.        ,
#          1.        ,  0.        ],
#        [ 0.72286285, -1.27859387, -0.70155141, ...,  1.        ,
#          0.        ,  0.        ]])

# %%
import optuna
from xgboost import XGBRegressor
from sklearn.metrics import mean_squared_error

def objective(trial):
    model = XGBRegressor(
        n_estimators=trial.suggest_int('n_estimators', 100, 800),
        learning_rate=trial.suggest_float('learning_rate', 0.005, 0.2),
        max_depth=trial.suggest_int('max_depth', 3, 12),
        subsample=trial.suggest_float('subsample', 0.6, 1.0),
        colsample_bytree=trial.suggest_float('colsample_bytree', 0.6, 1.0),
        reg_lambda=trial.suggest_float('reg_lambda', 0.1, 10.0),
        reg_alpha=trial.suggest_float('reg_alpha', 0.1, 10.0),
        gamma=trial.suggest_float('gamma', 0, 5),
        min_child_weight=trial.suggest_int('min_child_weight', 1, 10),
        random_state=42
    )
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    return mean_squared_error(y_test, y_pred)

study = optuna.create_study(direction='minimize')
study.optimize(objective, n_trials=50)
best_params = study.best_params

best_xgb = XGBRegressor(**best_params)
best_xgb.fit(X_train, y_train)
y_pred_xgb = best_xgb.predict(X_test)
# Out:
# [I 2025-02-18 16:52:59,261] A new study created in memory with name: no-name-fcc52fdf-0712-4d51-a86c-2d38d17eaa76
# [I 2025-02-18 16:53:34,674] Trial 0 finished with value: 1512.5529726697957 and parameters: {'n_estimators': 388, 'learning_rate': 0.025457099820793718, 'max_depth': 12, 'subsample': 0.8053194498793359, 'colsample_bytree': 0.9057054133998108, 'reg_lambda': 9.445907107486036, 'reg_alpha': 3.641517632338189, 'gamma': 4.147365363125369, 'min_child_weight': 8}. Best is trial 0 with value: 1512.5529726697957.
# [I 2025-02-18 16:53:40,779] Trial 1 finished with value: 3465.6356297329166 and parameters: {'n_estimators': 201, 'learning_rate': 0.19035164741046257, 'max_depth': 4, 'subsample': 0.906849221558546, 'colsample_bytree': 0.7771720318008701, 'reg_lambda': 1.338179037494193, 'reg_alpha': 1.7948380212327297, 'gamma': 3.792087386958186, 'min_child_weight': 1}. Best is trial 0 with value: 1512.5529726697957.
# [I 2025-02-18 16:54:02,986] Trial 2 finished with value: 17315.11327994976 and parameters: {'n_estimators': 223, 'learning_rate': 0.14352698839200242, 'max_depth': 9, 'subsample': 0.6852816261632669, 'colsample_bytree': 0.889928664196372, 'reg_lambda': 1.0508410809473832, 'reg_alpha': 4.372066040595224, 'gamma': 4.769754897801582, 'min_child_weight': 5}. Best is trial 0 with value: 1512.5529726697957.
# [I 2025-02-18 16:54:12,313] Trial 3 finished with value: 1594716.6702368294 and parameters: {'n_estimators': 132, 'learning_rate': 0.00597017426677747, 'max_depth': 8, 'subsample': 0.8545004773627738, 'colsample_bytree': 0.8476426524093307, 'reg_lambda': 9.033688713159236, 'reg_alpha': 3.048735853993106, 'gamma': 4.15374053921951, 'min_child_weight': 8}. Best is trial 0 with value: 1512.5529726697957.
# [I 2025-02-18 16:54:41,337] Trial 4 finished with value: 6383.107745903306 and parameters: {'n_estimators': 241, 'learning_rate': 0.18435824748330087, 'max_depth': 12, 'subsample': 0.9625733544196166, 'colsample_bytree': 0.8730040636432115, 'reg_lambda': 8.919362751952187, 'reg_alpha': 6.894607357153673, 'gamma': 3.6187047935796652, 'min_child_weight': 3}. Best is trial 0 with value: 1512.5529726697957.
# [I 2025-02-18 16:55:40,350] Trial 5 finished with value: 10633.753639910687 and parameters: {'n_estimators': 521, 'learning_rate': 0.10060492232289575, 'max_depth': 12, 'subsample': 0.9660867908742541, 'colsample_bytree': 0.6523679677726529, 'reg_lambda': 7.226531044674002, 'reg_alpha': 2.0115960135648843, 'gamma': 0.01790744812177003, 'min_child_weight': 6}. Best is trial 0 with value: 1512.5529726697957.
# [I 2025-02-18 16:56:25,676] Trial 6 finished with value: 16953.93510133964 and parameters: {'n_estimators': 691, 'learning_rate': 0.11587973146108665, 'max_depth': 12, 'subsample': 0.9618761392775635, 'colsample_bytree': 0.7155882092076074, 'reg_lambda': 2.652358488844469, 'reg_alpha': 5.896826342687593, 'gamma': 2.4642475099572043, 'min_child_weight': 6}. Best is trial 0 with value: 1512.5529726697957.
# [I 2025-02-18 16:57:10,539] Trial 7 finished with value: 15008.726934021459 and parameters: {'n_estimators': 551, 'learning_rate': 0.18038320279640427, 'max_depth': 9, 'subsample': 0.628612678823809, 'colsample_bytree': 0.6164357990425048, 'reg_lambda': 3.440624159366789, 'reg_alpha': 2.715661105502861, 'gamma': 1.5885852841569044, 'min_child_weight': 7}. Best is trial 0 with value: 1512.5529726697957.
# [I 2025-02-18 16:57:20,014] Trial 8 finished with value: 1804.7999700334738 and parameters: {'n_estimators': 213, 'learning_rate': 0.14204197503363247, 'max_depth': 5, 'subsample': 0.9546427693919587, 'colsample_bytree': 0.8750989759455852, 'reg_lambda': 6.622080134261832, 'reg_alpha': 5.212475355642024, 'gamma': 0.9504164468643672, 'min_child_weight': 6}. Best is trial 0 with value: 1512.5529726697957.
# [I 2025-02-18 16:57:47,025] Trial 9 finished with value: 1731.4192474523522 and parameters: {'n_estimators': 722, 'learning_rate': 0.1532964904225041, 'max_depth': 5, 'subsample': 0.9983800025893458, 'colsample_bytree': 0.7253537294995119, 'reg_lambda': 5.83434972675563, 'reg_alpha': 6.139532203264747, 'gamma': 0.32937493490235115, 'min_child_weight': 4}. Best is trial 0 with value: 1512.5529726697957.
# [I 2025-02-18 16:58:16,229] Trial 10 finished with value: 5366.098702922695 and parameters: {'n_estimators': 388, 'learning_rate': 0.01240437839002241, 'max_depth': 10, 'subsample': 0.7576422022686242, 'colsample_bytree': 0.9283577342395799, 'reg_lambda': 9.541512493818457, 'reg_alpha': 9.942395743236116, 'gamma': 2.7110287257784336, 'min_child_weight': 10}. Best is trial 0 with value: 1512.5529726697957.
# [I 2025-02-18 16:58:51,062] Trial 11 finished with value: 1025.6896573653382 and parameters: {'n_estimators': 718, 'learning_rate': 0.058132394959713736, 'max_depth': 6, 'subsample': 0.7990347502713139, 'colsample_bytree': 0.9951456181827801, 'reg_lambda': 5.471591905193292, 'reg_alpha': 7.721888943771281, 'gamma': 2.427534105299876, 'min_child_weight': 9}. Best is trial 11 with value: 1025.6896573653382.
# [I 2025-02-18 16:59:11,404] Trial 12 finished with value: 1103.217443824737 and parameters: {'n_estimators': 382, 'learning_rate': 0.05221323681298584, 'max_depth': 6, 'subsample': 0.7865326899466601, 'colsample_bytree': 0.9821443373497956, 'reg_lambda': 4.290152232691461, 'reg_alpha': 7.7689547429302515, 'gamma': 2.560320428304958, 'min_child_weight': 10}. Best is trial 11 with value: 1025.6896573653382.
# [I 2025-02-18 16:59:42,050] Trial 13 finished with value: 1088.6957751395737 and parameters: {'n_estimators': 607, 'learning_rate': 0.05577949942544943, 'max_depth': 6, 'subsample': 0.7374142517312617, 'colsample_bytree': 0.996234975829305, 'reg_lambda': 4.409502406138384, 'reg_alpha': 8.276870966667927, 'gamma': 2.456108973669559, 'min_child_weight': 10}. Best is trial 11 with value: 1025.6896573653382.
# [I 2025-02-18 17:00:03,038] Trial 14 finished with value: 1684.1715499565646 and parameters: {'n_estimators': 648, 'learning_rate': 0.06671715082439444, 'max_depth': 3, 'subsample': 0.7221032646344947, 'colsample_bytree': 0.9995841508641492, 'reg_lambda': 5.301803200992677, 'reg_alpha': 8.90822778131533, 'gamma': 1.8078483210004994, 'min_child_weight': 9}. Best is trial 11 with value: 1025.6896573653382.
# [I 2025-02-18 17:00:43,422] Trial 15 finished with value: 1122.8640163346336 and parameters: {'n_estimators': 599, 'learning_rate': 0.06358343683796853, 'max_depth': 7, 'subsample': 0.8583270066293797, 'colsample_bytree': 0.9525029049777824, 'reg_lambda': 4.148727540072457, 'reg_alpha': 0.2081178932601464, 'gamma': 1.8969397548154874, 'min_child_weight': 9}. Best is trial 11 with value: 1025.6896573653382.
# [I 2025-02-18 17:01:32,047] Trial 16 finished with value: 1898.8127333935474 and parameters: {'n_estimators': 760, 'learning_rate': 0.08916761081111477, 'max_depth': 7, 'subsample': 0.6587123125821752, 'colsample_bytree': 0.8193969202419421, 'reg_lambda': 7.647065149285208, 'reg_alpha': 8.128934932765583, 'gamma': 3.028416933722224, 'min_child_weight': 10}. Best is trial 11 with value: 1025.6896573653382.
# [I 2025-02-18 17:02:11,700] Trial 17 finished with value: 970.1704522339368 and parameters: {'n_estimators': 798, 'learning_rate': 0.041201137068450425, 'max_depth': 6, 'subsample': 0.7251243100894255, 'colsample_bytree': 0.9611633401554759, 'reg_lambda': 2.579253846353832, 'reg_alpha': 9.996052587281278, 'gamma': 3.2483272448936145, 'min_child_weight': 8}. Best is trial 17 with value: 970.1704522339368.
# [I 2025-02-18 17:02:34,831] Trial 18 finished with value: 1420.7687130942545 and parameters: {'n_estimators': 798, 'learning_rate': 0.031409534411396045, 'max_depth': 3, 'subsample': 0.8239166728250354, 'colsample_bytree': 0.9458470343284312, 'reg_lambda': 2.452779030897311, 'reg_alpha': 9.924884499988186, 'gamma': 3.326432108082357, 'min_child_weight': 8}. Best is trial 17 with value: 970.1704522339368.
# [I 2025-02-18 17:02:56,649] Trial 19 finished with value: 1834.9985774529246 and parameters: {'n_estimators': 496, 'learning_rate': 0.08546300424526249, 'max_depth': 5, 'subsample': 0.7011590822008377, 'colsample_bytree': 0.7729037652890247, 'reg_lambda': 0.4578275302153396, 'reg_alpha': 7.064704968260835, 'gamma': 4.984453371019268, 'min_child_weight': 7}. Best is trial 17 with value: 970.1704522339368.
# [I 2025-02-18 17:03:31,680] Trial 20 finished with value: 891.8804016576994 and parameters: {'n_estimators': 692, 'learning_rate': 0.0374781360721899, 'max_depth': 6, 'subsample': 0.6055023001384049, 'colsample_bytree': 0.9446255019395262, 'reg_lambda': 2.6316249936148735, 'reg_alpha': 9.022617531832548, 'gamma': 1.3684746888704715, 'min_child_weight': 7}. Best is trial 20 with value: 891.8804016576994.
# [I 2025-02-18 17:04:12,064] Trial 21 finished with value: 882.517844965304 and parameters: {'n_estimators': 799, 'learning_rate': 0.0334434958442328, 'max_depth': 6, 'subsample': 0.620259516675092, 'colsample_bytree': 0.9526780465359408, 'reg_lambda': 2.4608612265839325, 'reg_alpha': 9.03497284848793, 'gamma': 1.2200119627043635, 'min_child_weight': 7}. Best is trial 21 with value: 882.517844965304.
# [I 2025-02-18 17:05:11,296] Trial 22 finished with value: 1135.3121193554869 and parameters: {'n_estimators': 787, 'learning_rate': 0.0312409575725196, 'max_depth': 8, 'subsample': 0.6019909070748592, 'colsample_bytree': 0.9292852114232282, 'reg_lambda': 2.243905969166589, 'reg_alpha': 9.152604963470305, 'gamma': 0.9166312859194694, 'min_child_weight': 7}. Best is trial 21 with value: 882.517844965304.
# [I 2025-02-18 17:05:38,263] Trial 23 finished with value: 1008.4618722073635 and parameters: {'n_estimators': 662, 'learning_rate': 0.04046898038372761, 'max_depth': 4, 'subsample': 0.6514421556165237, 'colsample_bytree': 0.9554688296284648, 'reg_lambda': 3.2761999908786503, 'reg_alpha': 9.048167718474192, 'gamma': 1.353317375735489, 'min_child_weight': 5}. Best is trial 21 with value: 882.517844965304.
# [I 2025-02-18 17:06:26,008] Trial 24 finished with value: 3226.5231932059473 and parameters: {'n_estimators': 750, 'learning_rate': 0.0804690856348958, 'max_depth': 7, 'subsample': 0.6014252673253455, 'colsample_bytree': 0.8452738215727804, 'reg_lambda': 1.8034986013935517, 'reg_alpha': 9.339633591509283, 'gamma': 0.8442892460798039, 'min_child_weight': 7}. Best is trial 21 with value: 882.517844965304.
# [I 2025-02-18 17:06:58,717] Trial 25 finished with value: 1543.32284094861 and parameters: {'n_estimators': 628, 'learning_rate': 0.04240243324871558, 'max_depth': 6, 'subsample': 0.6679714691720606, 'colsample_bytree': 0.9072849530862478, 'reg_lambda': 0.3902357133084733, 'reg_alpha': 8.4935421844739, 'gamma': 2.080608388925759, 'min_child_weight': 8}. Best is trial 21 with value: 882.517844965304.
# [I 2025-02-18 17:07:26,522] Trial 26 finished with value: 1061.5023652801945 and parameters: {'n_estimators': 794, 'learning_rate': 0.02330707691009584, 'max_depth': 4, 'subsample': 0.6336534289625408, 'colsample_bytree': 0.971010702876, 'reg_lambda': 3.33511667413365, 'reg_alpha': 7.4440675283477225, 'gamma': 1.262425565488808, 'min_child_weight': 4}. Best is trial 21 with value: 882.517844965304.
# [I 2025-02-18 17:07:55,805] Trial 27 finished with value: 911.2469506965666 and parameters: {'n_estimators': 695, 'learning_rate': 0.07473658839310628, 'max_depth': 5, 'subsample': 0.7078808745533349, 'colsample_bytree': 0.9243344135533401, 'reg_lambda': 1.940374089146239, 'reg_alpha': 9.991983024536596, 'gamma': 0.49706064993268595, 'min_child_weight': 7}. Best is trial 21 with value: 882.517844965304.
# [I 2025-02-18 17:08:20,163] Trial 28 finished with value: 985.8880102143382 and parameters: {'n_estimators': 569, 'learning_rate': 0.07194620576266178, 'max_depth': 5, 'subsample': 0.6285321009859546, 'colsample_bytree': 0.9210098620450035, 'reg_lambda': 1.3986901346510097, 'reg_alpha': 6.54605601702729, 'gamma': 0.4247315985825587, 'min_child_weight': 5}. Best is trial 21 with value: 882.517844965304.
# [I 2025-02-18 17:08:37,747] Trial 29 finished with value: 1232.3988922045671 and parameters: {'n_estimators': 458, 'learning_rate': 0.11900965715683548, 'max_depth': 4, 'subsample': 0.6944254079350827, 'colsample_bytree': 0.9018532899839256, 'reg_lambda': 1.8778994778562623, 'reg_alpha': 8.604401356079851, 'gamma': 0.7443053814368048, 'min_child_weight': 6}. Best is trial 21 with value: 882.517844965304.
# [I 2025-02-18 17:09:29,338] Trial 30 finished with value: 2686.6724400562757 and parameters: {'n_estimators': 702, 'learning_rate': 0.0268125827885997, 'max_depth': 8, 'subsample': 0.7630504581789513, 'colsample_bytree': 0.8450537894737071, 'reg_lambda': 3.1635845635686377, 'reg_alpha': 5.335526118385405, 'gamma': 1.2675124975364327, 'min_child_weight': 7}. Best is trial 21 with value: 882.517844965304.
# [I 2025-02-18 17:10:09,406] Trial 31 finished with value: 1004.9049369041642 and parameters: {'n_estimators': 743, 'learning_rate': 0.04743986550590375, 'max_depth': 6, 'subsample': 0.7160877078957324, 'colsample_bytree': 0.9558986041824843, 'reg_lambda': 2.7245965981367193, 'reg_alpha': 9.973458174668044, 'gamma': 0.4679616039516864, 'min_child_weight': 8}. Best is trial 21 with value: 882.517844965304.
# [I 2025-02-18 17:10:39,951] Trial 32 finished with value: 1152.7540697928098 and parameters: {'n_estimators': 674, 'learning_rate': 0.016421174276323974, 'max_depth': 5, 'subsample': 0.6735781679535893, 'colsample_bytree': 0.9299966418904865, 'reg_lambda': 1.1702262961088505, 'reg_alpha': 9.402221209316123, 'gamma': 0.11350335481629725, 'min_child_weight': 8}. Best is trial 21 with value: 882.517844965304.
# [I 2025-02-18 17:11:23,813] Trial 33 finished with value: 927.5823754061581 and parameters: {'n_estimators': 756, 'learning_rate': 0.04157732274168156, 'max_depth': 7, 'subsample': 0.6423269886131314, 'colsample_bytree': 0.9691148056126655, 'reg_lambda': 3.9077593685171848, 'reg_alpha': 9.517304202090058, 'gamma': 4.125921237126855, 'min_child_weight': 9}. Best is trial 21 with value: 882.517844965304.
# [I 2025-02-18 17:12:08,187] Trial 34 finished with value: 2207.1673547122455 and parameters: {'n_estimators': 686, 'learning_rate': 0.07372503225613872, 'max_depth': 7, 'subsample': 0.6378624518560753, 'colsample_bytree': 0.8863262317941027, 'reg_lambda': 3.8814276986574754, 'reg_alpha': 9.320409272105211, 'gamma': 1.546791042692006, 'min_child_weight': 1}. Best is trial 21 with value: 882.517844965304.
# [I 2025-02-18 17:13:06,355] Trial 35 finished with value: 1700.8489974856377 and parameters: {'n_estimators': 739, 'learning_rate': 0.0334285286810522, 'max_depth': 9, 'subsample': 0.610458798446991, 'colsample_bytree': 0.9111493307111174, 'reg_lambda': 1.8272026122810274, 'reg_alpha': 3.7457706771556882, 'gamma': 4.220598541020754, 'min_child_weight': 9}. Best is trial 21 with value: 882.517844965304.
# [I 2025-02-18 17:13:31,670] Trial 36 finished with value: 1340.8052795805283 and parameters: {'n_estimators': 337, 'learning_rate': 0.09973653812293612, 'max_depth': 8, 'subsample': 0.689455401038277, 'colsample_bytree': 0.941788999654388, 'reg_lambda': 4.91852999289064, 'reg_alpha': 8.07574024887512, 'gamma': 4.435168632485051, 'min_child_weight': 7}. Best is trial 21 with value: 882.517844965304.
# [I 2025-02-18 17:14:18,439] Trial 37 finished with value: 8698.357693379787 and parameters: {'n_estimators': 641, 'learning_rate': 0.005520658683495411, 'max_depth': 7, 'subsample': 0.6527717537941302, 'colsample_bytree': 0.9776420264644191, 'reg_lambda': 0.7867006947906237, 'reg_alpha': 8.712872009843094, 'gamma': 3.8755248065588797, 'min_child_weight': 6}. Best is trial 21 with value: 882.517844965304.
# [I 2025-02-18 17:14:24,150] Trial 38 finished with value: 4933.172213549823 and parameters: {'n_estimators': 108, 'learning_rate': 0.051652426887641024, 'max_depth': 4, 'subsample': 0.624673198304152, 'colsample_bytree': 0.863829650790143, 'reg_lambda': 3.8529987533287455, 'reg_alpha': 7.228718242982563, 'gamma': 0.9997267942390571, 'min_child_weight': 4}. Best is trial 21 with value: 882.517844965304.
# [I 2025-02-18 17:14:49,285] Trial 39 finished with value: 2169.202904975765 and parameters: {'n_estimators': 583, 'learning_rate': 0.02046521140880548, 'max_depth': 5, 'subsample': 0.6725113137137998, 'colsample_bytree': 0.7865375303229027, 'reg_lambda': 0.10807957307468463, 'reg_alpha': 4.457271270648481, 'gamma': 0.6388103034975124, 'min_child_weight': 2}. Best is trial 21 with value: 882.517844965304.
# [I 2025-02-18 17:15:17,736] Trial 40 finished with value: 4624.249088314275 and parameters: {'n_estimators': 276, 'learning_rate': 0.11534091260786315, 'max_depth': 10, 'subsample': 0.6519841318899159, 'colsample_bytree': 0.8877951542084415, 'reg_lambda': 2.8975862331250215, 'reg_alpha': 9.448450406895548, 'gamma': 2.1350985359536976, 'min_child_weight': 6}. Best is trial 21 with value: 882.517844965304.
# [I 2025-02-18 17:15:55,563] Trial 41 finished with value: 949.3787892181007 and parameters: {'n_estimators': 765, 'learning_rate': 0.04022082506302523, 'max_depth': 6, 'subsample': 0.7390709729717787, 'colsample_bytree': 0.9690373878204449, 'reg_lambda': 2.249173735567502, 'reg_alpha': 9.728054025764985, 'gamma': 3.5228624272272877, 'min_child_weight': 9}. Best is trial 21 with value: 882.517844965304.
# [I 2025-02-18 17:16:32,004] Trial 42 finished with value: 938.0903405966349 and parameters: {'n_estimators': 766, 'learning_rate': 0.037285229228060976, 'max_depth': 6, 'subsample': 0.7045887089449334, 'colsample_bytree': 0.9688745344479339, 'reg_lambda': 2.039159267808618, 'reg_alpha': 9.507650309133826, 'gamma': 3.7416582541351047, 'min_child_weight': 9}. Best is trial 21 with value: 882.517844965304.
# [I 2025-02-18 17:17:13,171] Trial 43 finished with value: 1816.133991566853 and parameters: {'n_estimators': 706, 'learning_rate': 0.19961271460559482, 'max_depth': 7, 'subsample': 0.617601018072971, 'colsample_bytree': 0.9772548999265166, 'reg_lambda': 1.5442627722674138, 'reg_alpha': 8.749648477277676, 'gamma': 3.928485391693691, 'min_child_weight': 8}. Best is trial 21 with value: 882.517844965304.
# [I 2025-02-18 17:17:37,999] Trial 44 finished with value: 1784.7248235551629 and parameters: {'n_estimators': 533, 'learning_rate': 0.012249029596189509, 'max_depth': 5, 'subsample': 0.693939061864292, 'colsample_bytree': 0.9358577597912008, 'reg_lambda': 4.764490258513761, 'reg_alpha': 7.945742357767635, 'gamma': 4.501458933740029, 'min_child_weight': 9}. Best is trial 21 with value: 882.517844965304.
# [I 2025-02-18 17:18:16,205] Trial 45 finished with value: 1246.370258000952 and parameters: {'n_estimators': 716, 'learning_rate': 0.061138957202188655, 'max_depth': 6, 'subsample': 0.6407549404035762, 'colsample_bytree': 0.9112717428785535, 'reg_lambda': 3.726183500109215, 'reg_alpha': 6.636016041533036, 'gamma': 4.62728502500304, 'min_child_weight': 5}. Best is trial 21 with value: 882.517844965304.
# [I 2025-02-18 17:19:11,936] Trial 46 finished with value: 10582.227188770577 and parameters: {'n_estimators': 769, 'learning_rate': 0.04868962551015933, 'max_depth': 8, 'subsample': 0.7608780140326933, 'colsample_bytree': 0.6927929827727994, 'reg_lambda': 0.939822838003753, 'reg_alpha': 9.579112281749254, 'gamma': 4.176856104040894, 'min_child_weight': 7}. Best is trial 21 with value: 882.517844965304.
# [I 2025-02-18 17:19:22,070] Trial 47 finished with value: 3692.0561776534464 and parameters: {'n_estimators': 169, 'learning_rate': 0.03386428661002025, 'max_depth': 6, 'subsample': 0.885209163101262, 'colsample_bytree': 0.8624045967863623, 'reg_lambda': 2.0589978677144667, 'reg_alpha': 9.076820927303881, 'gamma': 2.8999709709380506, 'min_child_weight': 10}. Best is trial 21 with value: 882.517844965304.
# [I 2025-02-18 17:19:46,351] Trial 48 finished with value: 1092.5324267933158 and parameters: {'n_estimators': 622, 'learning_rate': 0.0927496117144762, 'max_depth': 5, 'subsample': 0.7081709736562806, 'colsample_bytree': 0.9913663644070765, 'reg_lambda': 6.017332296493496, 'reg_alpha': 7.640292199517011, 'gamma': 1.6019209485002532, 'min_child_weight': 9}. Best is trial 21 with value: 882.517844965304.
# [I 2025-02-18 17:20:34,415] Trial 49 finished with value: 2976.1107915593693 and parameters: {'n_estimators': 733, 'learning_rate': 0.07183282930488745, 'max_depth': 7, 'subsample': 0.6766804991864177, 'colsample_bytree': 0.8109910796254783, 'reg_lambda': 2.98669452754304, 'reg_alpha': 8.308055849305905, 'gamma': 0.20296931807409585, 'min_child_weight': 7}. Best is trial 21 with value: 882.517844965304.

# %%
evaluate_model("New_XGB", y_test, y_pred_xgb)
# Out:
#  New_XGB Performance:
# R² Score: 0.9998
# MAE: 23.1816
# RMSE: 31.3595

# %%
y_over = best_xgb.predict(X_train)

# %%
evaluate_model("New_XGB", y_train, y_over)
# Out:
#  New_XGB Performance:
# R² Score: 1.0000
# MAE: 10.5978
# RMSE: 13.6961
