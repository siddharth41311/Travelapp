# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import random
# %matplotlib inline

# %%
flight_positive = pd.read_csv('flight_positive_reviews.csv')['positive reviews'].tolist()
flight_neutral = pd.read_csv('flight_neutral_reviews.csv')['neutral reviews'].tolist()
flight_negative = pd.read_csv('flight_negative_reviews.csv')['negative reviews'].tolist()

# %%
all_reviews = flight_positive+flight_neutral+flight_negative

# %%
random.seed(101)

# %%
random.shuffle(all_reviews)

# %%
all_reviews
# Out:
# ['The flight was completely poor. The flight entertainment was awful, and the turbulence handling was unacceptable.',
#  'Absolutely fantastic! The top-notch was WiFi speed and the punctuality made my journey comfortable.',
#  "Didn't impress, but didn't disappoint either. The reasonable was overhead storage, and the legroom was alright.",
#  "Didn't impress, but didn't disappoint either. The standard was food quality, and the check-in process was alright.",
#  'Worst flight ever! The poor was boarding process and the flight entertainment ruined my experience.',
#  'The flight was comfortable. The baggage handling was excellent, and the food quality made it even better.',
#  'Had high hopes, but the awful was air conditioning and the customer service was disappointing.',
#  'A huge disappointment. The uncomfortable was crew friendliness and the turbulence handling was below standard.',
#  'It was a disaster! The frustrating was customer service and the security was simply awful.',
# ...

# %%
positive = pd.read_csv('flight_positive_reviews.csv')
neutral = pd.read_csv('flight_neutral_reviews.csv')
negative = pd.read_csv('flight_negative_reviews.csv')

# %%
positive.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2685 entries, 0 to 2684
# Data columns (total 2 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   sentiment         2685 non-null   object
#  1   positive reviews  2685 non-null   object
# dtypes: object(2)
# memory usage: 42.1+ KB

# %%
neutral.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2842 entries, 0 to 2841
# Data columns (total 2 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   sentiment        2842 non-null   object
#  1   neutral reviews  2842 non-null   object
# dtypes: object(2)
# memory usage: 44.5+ KB

# %%
negative.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2844 entries, 0 to 2843
# Data columns (total 2 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   sentiment         2844 non-null   object
#  1   negative reviews  2844 non-null   object
# dtypes: object(2)
# memory usage: 44.6+ KB

# %%
file_path = r"C:\Users\hp\Downloads\archive (2)\FlightFINALdataset.xlsx"
flight_df = pd.read_excel(file_path)

# %%
num_rows = len(flight_df)

# %%
selected_indices = random.sample(range(num_rows),8371)

# %%
print(f"Total rows: {num_rows}")
print(f"Selected indices: {selected_indices[:5]}")
# Out:
# Total rows: 40552
# Selected indices: [26822, 271, 7286, 34856, 20840]

# %%
flight_df['Review_text'] = ""

# %%
for i,idx in enumerate(selected_indices):
    flight_df.at[idx,'Review_text'] = all_reviews[i]

# %%
flight_df
# Out:
#        travelCode  User_ID           Departure             Arrival  \
# 0               0        0         Recife (PE)  Florianopolis (SC)
# 1               2        0        Aracaju (SE)       Salvador (BH)
# 2               7        0        Aracaju (SE)       Salvador (BH)
# 3              11        0       Brasilia (DF)       Salvador (BH)
# 4              13        0         Recife (PE)  Florianopolis (SC)
# ...           ...      ...                 ...                 ...
# 40547      135938     1339  Florianopolis (SC)       Brasilia (DF)
# 40548      135939     1339  Florianopolis (SC)       Brasilia (DF)
# 40549      135940     1339  Florianopolis (SC)   Campo Grande (MS)
# 40550      135941     1339  Florianopolis (SC)   Campo Grande (MS)
# 40551      135942     1339  Florianopolis (SC)          Natal (RN)
#
#        flightType  Flight_price  Flight_duration  Flight_Distance  \
# 0      firstClass       1434.38             1.76           676.53
# ...

# %%
pip install openpyxl
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution ~ensorflow-intel (C:\Users\hp\AppData\Roaming\Python\Python311\site-packages)
# WARNING: Ignoring invalid distribution ~ensorflow-intel (C:\Users\hp\AppData\Roaming\Python\Python311\site-packages)
# WARNING: Ignoring invalid distribution ~ensorflow-intel (C:\Users\hp\AppData\Roaming\Python\Python311\site-packages)
#
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
flight_df.to_excel('Flight_FR.xlsx',index=False)

# %%
hotel_positive = pd.read_csv('hotel_positive_reviews.csv')['positive reviews'].tolist()
hotel_neutral = pd.read_csv('hotel_neutral_reviews.csv')['neutral reviews'].tolist()
hotel_negative = pd.read_csv('hotel_negative_reviews.csv')['negative reviews'].tolist()

# %%
all_reviews = hotel_positive+hotel_neutral+hotel_negative

# %%
random.shuffle(all_reviews)

# %%
all_reviews
# Out:
# ['A decent stay. The standard was WiFi speed, and the check-in process could have been better.',
#  "I can't believe how unacceptable this place was. The gym was a disaster and the room cleanliness was appalling.",
#  "If you're looking for a basic stay, this is okay. The decent was air conditioning, and the breakfast options was neutral.",
#  'The stay was completely dreadful. The customer service was awful, and the check-in process was unacceptable.',
#  'Highly recommend this place! The spotless was restaurant service, and the view from the room was simply fantastic.',
#  'It was a nightmare! The unacceptable was check-in process and the security was simply horrible.',
#  'The stay was completely unacceptable. The breakfast options was awful, and the staff friendliness was unacceptable.',
#  'I loved the place! The luxurious was so pool, and the view from the room made my stay truly special.',
# ...

# %%
positive = pd.read_csv('hotel_positive_reviews.csv')
neutral = pd.read_csv('hotel_neutral_reviews.csv')
negative = pd.read_csv('hotel_negative_reviews.csv')

# %%
positive.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2824 entries, 0 to 2823
# Data columns (total 2 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   sentiment         2824 non-null   object
#  1   positive reviews  2824 non-null   object
# dtypes: object(2)
# memory usage: 44.3+ KB

# %%
neutral.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2894 entries, 0 to 2893
# Data columns (total 2 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   sentiment        2894 non-null   object
#  1   neutral reviews  2894 non-null   object
# dtypes: object(2)
# memory usage: 45.3+ KB

# %%
negative.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2929 entries, 0 to 2928
# Data columns (total 2 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   sentiment         2929 non-null   object
#  1   negative reviews  2929 non-null   object
# dtypes: object(2)
# memory usage: 45.9+ KB

# %%
file_path = r"C:\Users\hp\Downloads\archive (2)\Hotel_1Final.xlsx"
hotel_df = pd.read_excel(file_path)

# %%
num_rows = len(hotel_df)

# %%
random.seed(56)

# %%
selected_indices = random.sample(range(num_rows),8647)

# %%
print(f"Total rows: {num_rows}")
print(f"Selected indices: {selected_indices[:5]}")
# Out:
# Total rows: 40552
# Selected indices: [36684, 753, 31042, 34293, 19735]

# %%
hotel_df['Review_text'] = ""

# %%
for i,idx in enumerate(selected_indices):
    hotel_df.at[idx,'Review_text'] = all_reviews[i]

# %%
hotel_df
# Out:
#        User_ID  travelCode              Hotel_Name       Arrival_place  \
# 0            0           0    The Sapphire Retreat  Florianopolis (SC)
# 1            0           2           Oceanview Inn       Salvador (BH)
# 2            0           7           Oceanview Inn       Salvador (BH)
# 3            0          11           Oceanview Inn       Salvador (BH)
# 4            0          13     Horizon Cliff Hotel  Florianopolis (SC)
# ...        ...         ...                     ...                 ...
# 40547     1339      135938  Tranquil Meadows Hotel       Brasilia (DF)
# 40548     1339      135939  Tranquil Meadows Hotel       Brasilia (DF)
# 40549     1339      135940         Evergreen Lodge   Campo Grande (MS)
# 40550     1339      135941    Summit Heights Hotel   Campo Grande (MS)
# 40551     1339      135942      Emerald Bay Resort          Natal (RN)
#
#        Hotel_stay  Hotel_per_day_price    Check-in  Hotel_TotalPrice  \
# ...

# %%
hotel_df.to_excel('Hotel_FR.xlsx',index=False)

# %%
car_positive = pd.read_csv('car_positive_reviews.csv')['positive reviews'].tolist()
car_neutral = pd.read_csv('car_neutral_reviews.csv')['neutral reviews'].tolist()
car_negative = pd.read_csv('car_negative_reviews.csv')['negative reviews'].tolist()

# %%
all_reviews = car_positive+car_neutral+car_negative

# %%
random.shuffle(all_reviews)

# %%
all_reviews
# Out:
# ['Nothing exceptional, but nothing terrible either. The mediocre was return policy, and the booking ease was fine.',
#  'Avoid this rental service! The disappointing was hidden fees and the pickup process was a nightmare.',
#  'Nothing too exciting. The mediocre was return policy, and the staff professionalism was just okay.',
#  'Such a smooth rental process! The impressive was GPS availability and the waiting time was just perfect.',
#  'It was a disaster! The awful was pricing and the staff professionalism was simply awful.',
#  "If you're looking for great service, this is it! The smooth was waiting time, and the customer service was flawless.",
#  'A huge disappointment. The frustrating was tire condition and the vehicle condition was below standard.',
#  'A huge disappointment. The miserable was car cleanliness and the waiting time was below standard.',
#  'The rental experience was poor. The deposit policy was awful, and the insurance options was unacceptable.',
# ...

# %%
positive = pd.read_csv('car_positive_reviews.csv')
neutral = pd.read_csv('car_neutral_reviews.csv')
negative = pd.read_csv('car_negative_reviews.csv')

# %%
positive.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2725 entries, 0 to 2724
# Data columns (total 2 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   sentiment         2725 non-null   object
#  1   positive reviews  2725 non-null   object
# dtypes: object(2)
# memory usage: 42.7+ KB

# %%
negative.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2896 entries, 0 to 2895
# Data columns (total 2 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   sentiment         2896 non-null   object
#  1   negative reviews  2896 non-null   object
# dtypes: object(2)
# memory usage: 45.4+ KB

# %%
neutral.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2872 entries, 0 to 2871
# Data columns (total 2 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   sentiment        2872 non-null   object
#  1   neutral reviews  2872 non-null   object
# dtypes: object(2)
# memory usage: 45.0+ KB

# %%
file_path = r"C:\Users\hp\Downloads\archive (2)\CarFINALdataset.xlsx"
car_df = pd.read_excel(file_path)

# %%
num_rows = len(car_df)

# %%
random.seed(70)

# %%
selected_indices = random.sample(range(num_rows),3773)

# %%
print(f"Total rows: {num_rows}")
print(f"Selected indices: {selected_indices[:5]}")
# Out:
# Total rows: 3773
# Selected indices: [3726, 485, 1204, 2879, 1881]

# %%
car_df['Review_text'] = ""

# %%
for i,idx in enumerate(selected_indices):
    car_df.at[idx,'Review_text'] = all_reviews[i]

# %%
car_df.head(20)
# Out:
#     User_ID  travelCode    Check-in      pickupLocation   dropoffLocation  \
# 0         0          22  02/27/2020            Johntown        Port Brian
# 1         0          45  08/06/2020           Owensland          Ruizfort
# 2         2         117  02/27/2020          Edwardview         Katiefort
# 3         2         119  03/12/2020        Moranborough    Lake Stephanie
# 4         2         153  11/05/2020    Port Kathrynstad   East Ronnieberg
# 5         3         255  04/16/2020  East Jenniferhaven      South Meghan
# 6         3         283  10/29/2020        Martinezberg    New Josephfort
# 7         3         305  04/01/2021          Brandistad    Lake Alexander
# 8         3         338  11/18/2021        Gonzalezberg     West Margaret
# 9         3         385  10/13/2022    North Caseyburgh      South Carrie
# 10        3         387  10/27/2022          Hansonfurt      Lake Shannon
# 11        4         517  07/01/2021         Carterhaven      Marquezville
# ...

# %%
car_df.to_excel('Car_FR.xlsx',index=False)

# %%
# !pip install transformers torch
import pandas as pd
import torch
from transformers import BertTokenizer, BertForSequenceClassification
from sklearn.model_selection import train_test_split
from torch.utils.data import DataLoader, Dataset
from transformers import AdamW, get_linear_schedule_with_warmup
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import classification_report
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# WARNING: Ignoring invalid distribution ~ensorflow-intel (C:\Users\hp\AppData\Roaming\Python\Python311\site-packages)
# WARNING: Ignoring invalid distribution ~ensorflow-intel (C:\Users\hp\AppData\Roaming\Python\Python311\site-packages)
# WARNING: Ignoring invalid distribution ~ensorflow-intel (C:\Users\hp\AppData\Roaming\Python\Python311\site-packages)
#
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
